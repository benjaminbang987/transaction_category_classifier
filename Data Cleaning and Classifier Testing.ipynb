# %%
import pandas as pd
import re

# %%
df = pd.read_csv("./training_data.csv")
df.columns = [x.lower().replace(' ', '_') for x in df.columns]

# %%
df["amount"] = df["amount"].apply(lambda x: x.replace(',', '').replace('$', '').replace('−', '-'))
df["amount"] = df["amount"].astype(float)

# %%
df["category"] = df["category"].str.lower()
df.head()
# Out:
#   purchased_at                     description  category   amount
# 0     7/1/2017                            Rent      rent  1395.00
# 1     7/4/2017          Nelnet Group B Payback      loan   500.00
# 2     7/5/2017                   Uber from SFO    travel    26.30
# 3     7/5/2017  IKEA - Bed frames, sheets, etc  personal   127.20
# 4     7/5/2017            Walgreens - sandwich      food     2.99

# %%
df.head()
# Out:
#   purchased_at                     description  category   amount
# 0     7/1/2017                            Rent      rent  1395.00
# 1     7/4/2017          Nelnet Group B Payback      loan   500.00
# 2     7/5/2017                   Uber from SFO    travel    26.30
# 3     7/5/2017  IKEA - Bed frames, sheets, etc  personal   127.20
# 4     7/5/2017            Walgreens - sandwich      food     2.99

# %%
# Besides the amount and the date field, the string "description" field contains the most information.
# We can extract features from it and run XGBoost, or we can fine-tune the pretrained Embeddings Model
# Let's do the first one with XGBoost

# %%
# let's create some features based off of "Description"
# Rent feature
df["is_rent"] = df["description"].str.match("rent", case=False)
# Utility features
df["is_pge"] = df["description"].str.contains("[\s\S]*pg[\s\S]*e", flags=re.IGNORECASE, regex=True)
df["is_xfinity"] = df["description"].str.contains("[\s\S]*xfinity[\s\S]*|[\s\S]*comcast[\s\S]*", flags=re.IGNORECASE, regex=True)

# %%
# Auto features
df["is_gas"] = df["description"].str.contains("[\s]gas", case=False)

# %%
df
# Out:
#      purchased_at                     description  category   amount  is_rent  \
# 0        7/1/2017                            Rent      rent  1395.00     True
# 1        7/4/2017          Nelnet Group B Payback      loan   500.00    False
# 2        7/5/2017                   Uber from SFO    travel    26.30    False
# 3        7/5/2017  IKEA - Bed frames, sheets, etc  personal   127.20    False
# 4        7/5/2017            Walgreens - sandwich      food     2.99    False
# ...           ...                             ...       ...      ...      ...
# 2938     2/4/2023           Venmo - Ebisu with 목장      food    46.30    False
# 2939     2/4/2023    Hometown Creamry - Ice Cream      food     4.50    False
# 2940     2/4/2023               Sightglass Coffee      food     4.43    False
# 2941     2/5/2023           Venmo - Yayoi with 목장      food    27.00    False
# 2942     2/6/2023                Mendochino Farms      food    19.43    False
#
#       is_pge  is_xfinity  is_gas
# 0      False       False   False
# 1      False       False   False
# 2      False       False   False
# 3      False       False   False
# 4      False       False   False
# ...      ...         ...     ...
# 2938   False       False   False
# 2939   False       False   False
# 2940   False       False   False
# 2941   False       False   False
# 2942   False       False   False
#
# [2943 rows x 8 columns]
